# %% [markdown]
# 生成所有数据的主文件，以及扔给DeepSeek训练的数据。

# %% [markdown]
# ## 创建数据库

# %%
from app import app
from app.extensions import db

with app.app_context():
    db.drop_all()
    db.create_all()

print("已重新生成数据表结构")
# Out:
# 已重新生成数据表结构

# %% [markdown]
# ## 生成用户
#
# - 共生成100个用户，用户名和密码用Faker库生成。

# %%
from app.models import User
from app.constants import UserRole, UserStatus
from app.extensions import db
from app import app
import faker

fake = faker.Faker("zh_CN")

count = 50
users = []

for index in range(count):
    username = fake.user_name()
    user = User(
        username=username,
        password=username,
        role=UserRole.User.value,
        state=UserStatus.Active.value,
    )
    users.append(user)
    print(f"准备添加第{index}名用户，用户名={user.username} 密码={user.password}")

users[0].role = UserRole.Admin.value
users[0].username = 'admin'
users[0].password = '123456'
users[1].role = UserRole.Admin.value
users[-1].state = UserStatus.Banned.value

with app.app_context():
    db.session.add_all(users)
    db.session.commit()

print(f"已添加{count}名用户")
# Out:
# 准备添加第0名用户，用户名=juan92 密码=juan92
# 准备添加第1名用户，用户名=panping 密码=panping
# 准备添加第2名用户，用户名=lqin 密码=lqin
# 准备添加第3名用户，用户名=jingguo 密码=jingguo
# 准备添加第4名用户，用户名=vpeng 密码=vpeng
# 准备添加第5名用户，用户名=liaojie 密码=liaojie
# 准备添加第6名用户，用户名=yongjia 密码=yongjia
# 准备添加第7名用户，用户名=yumin 密码=yumin
# 准备添加第8名用户，用户名=lwen 密码=lwen
# 准备添加第9名用户，用户名=gongjie 密码=gongjie
# 准备添加第10名用户，用户名=baiqiang 密码=baiqiang
# 准备添加第11名用户，用户名=liaoqiang 密码=liaoqiang
# 准备添加第12名用户，用户名=cren 密码=cren
# 准备添加第13名用户，用户名=yong27 密码=yong27
# 准备添加第14名用户，用户名=guiyingxia 密码=guiyingxia
# 准备添加第15名用户，用户名=xiulan59 密码=xiulan59
# 准备添加第16名用户，用户名=xzhong 密码=xzhong
# 准备添加第17名用户，用户名=guiyingdong 密码=guiyingdong
# 准备添加第18名用户，用户名=juanzeng 密码=juanzeng
# 准备添加第19名用户，用户名=mengjie 密码=mengjie
# 准备添加第20名用户，用户名=kduan 密码=kduan
# 准备添加第21名用户，用户名=jie28 密码=jie28
# 准备添加第22名用户，用户名=yan40 密码=yan40
# 准备添加第23名用户，用户名=lei94 密码=lei94
# 准备添加第24名用户，用户名=xwan 密码=xwan
# 准备添加第25名用户，用户名=duming 密码=duming
# 准备添加第26名用户，用户名=guiyingchen 密码=guiyingchen
# 准备添加第27名用户，用户名=qiujie 密码=qiujie
# 准备添加第28名用户，用户名=na57 密码=na57
# 准备添加第29名用户，用户名=nding 密码=nding
# 准备添加第30名用户，用户名=nmao 密码=nmao
# 准备添加第31名用户，用户名=junduan 密码=junduan
# 准备添加第32名用户，用户名=naduan 密码=naduan
# 准备添加第33名用户，用户名=pingzhong 密码=pingzhong
# 准备添加第34名用户，用户名=chao44 密码=chao44
# 准备添加第35名用户，用户名=li72 密码=li72
# 准备添加第36名用户，用户名=shijun 密码=shijun
# 准备添加第37名用户，用户名=mingqin 密码=mingqin
# 准备添加第38名用户，用户名=leiliao 密码=leiliao
# 准备添加第39名用户，用户名=nma 密码=nma
# 准备添加第40名用户，用户名=nagao 密码=nagao
# 准备添加第41名用户，用户名=qiang49 密码=qiang49
# 准备添加第42名用户，用户名=fyi 密码=fyi
# 准备添加第43名用户，用户名=lei03 密码=lei03
# 准备添加第44名用户，用户名=xiawang 密码=xiawang
# 准备添加第45名用户，用户名=gulei 密码=gulei
# 准备添加第46名用户，用户名=jialei 密码=jialei
# 准备添加第47名用户，用户名=xiapeng 密码=xiapeng
# 准备添加第48名用户，用户名=yangpeng 密码=yangpeng
# 准备添加第49名用户，用户名=liujuan 密码=liujuan
# 已添加50名用户

# %% [markdown]
# ## 添加用户信息
#
# 昵称已预设，昵称随机生成，80来自本地，20来自河南郑州。

# %%
from app.models import UserInformation

from pathlib import Path
from shutil import copy

# 先移除所有文件

folder = Path("../uploads")
for item in folder.iterdir():
    if item.is_file():
        item.unlink()
    elif item.is_dir():
        item.rmdir()
print(f"已删除 {folder} 下的所有文件")

# 复制文件
folder = Path('./avatars/')

avatars = [f for f in folder.iterdir() if f.is_file()]

print(f"共{len(avatars)}张头像")

for avatar in avatars:
    copy(avatar, f'../uploads/{avatar.name}')

copy('./assets/imgs/avatar.png', '../uploads/avatar.png')
copy('./assets/imgs/wallpaper.png', '../uploads/wallpaper.png')

print(f"已复制头像")

nicknames = [
    "秦皇岛山海关发布",
    "秦皇岛北戴河官微",
    "秦皇岛野生动物园官方",
    "秦皇岛阿那亚旅游局",
    "秦皇岛老虎石海上公园",
    "秦皇岛鸽子窝官方",
    "秦皇岛奥林匹克公园",
    "秦皇岛南戴河官方号",
    "秦皇岛新澳海底世界",
    "秦皇岛祖山景区",
    "秦皇岛求仙入海处",
    "秦皇岛黄金海岸官号",
    "秦皇岛港口博物馆",
    "秦皇岛西港花园景区",
    "秦皇岛桃林口水库",
    "秦皇岛燕塞湖管理处",
    "秦皇岛怪楼奇园官方",
    "秦皇岛集发农业观光园",
    "秦皇岛山海文化公园",
    "秦皇岛滨海森林公园",
    "今天也想躺着",
    "海盐味的风",
    "月亮不营业",
    "桃子汽水",
    "晚风不等人",
    "小熊软糖不软",
    "一只会发光的猫",
    "日落之后",
    "奶茶味的日常",
    "想和你看海",
    "今夜星光灿烂",
    "豆乳拿铁少女",
    "凌晨三点的梦",
    "藏在云里的光",
    "甜味泡泡鱼",
    "焦糖味星球",
    "奶盖多多哒",
    "听说你很甜",
    "风住了星星",
    "宇宙小卖部",
    "夏天的柠檬汽",
    "温柔只给你",
    "爱吃小饼干",
    "猫系少女已上线",
    "在逃煎蛋卷",
    "翻滚的小章鱼",
    "打烊的奶茶店",
    "软绵绵的天气",
    "冬日限定热可可",
    "与你有关的风",
    "跑调的小曲奇",
    "追光的橘子",
    "甜到掉牙",
    "耳机里的温柔",
    "落日海岸线",
    "今日份可爱",
    "撒糖小天使",
    "凌晨的月亮",
    "猫窝日记本",
    "风吹少女裙",
    "奶油草莓派",
    "不想上班的咸鱼",
    "橘子汽泡水",
    "白日梦制造机",
    "温柔收容所",
    "躲进云朵里",
    "星河漫游指南",
    "斑斓泡泡",
    "镜子里的小怪兽",
    "随缘小辣椒",
    "野生柠檬茶",
    "风把耳朵吹红了",
    "冒泡的鲸鱼",
    "玫瑰味的宇宙",
    "鱼与西柚",
    "今天不营业",
    "月亮邮局",
    "沙滩捡壳人",
    "雨后起司蛋糕",
    "水蜜桃星球",
    "不加糖的可乐",
    "森林小偷",
    "今日开心了吗",
    "养猫少女",
    "我在云上写日记",
    "流浪星球旅客",
    "草莓味小夜灯",
    "梦里有猫",
    "清醒梦游者",
    "风中的菠萝包",
    "温柔的果冻",
    "可乐加点冰",
    "捡星星的人",
    "月亮派来的信使",
    "今天想你了",
    "云端甜品师",
    "住在森林的鲸",
    "穿裙子的夏天",
    "芒果气泡水",
    "想念变得很甜",
]

count = 50

print(f"共{len(nicknames)}个昵称")

provinces = ["河北省"] * int(count * 0.4)
provinces.extend(["河南省"] * (count - len(provinces)))

cities = ["秦皇岛市"] * int(count * 0.4)
cities.extend(["郑州市"] * (count - len(cities)))

informations = []

for index, (nickname, provinces, cities, avatar) in enumerate(zip(nicknames, provinces, cities, avatars)):
    information = UserInformation(
        user_id=index + 1,
        nickname=nickname,
        position_province=provinces,
        position_city=cities,
        avatar_path=f"https://localhost:5000/download/{avatar.name}"
    )
    informations.append(information)

with app.app_context():
    db.session.add_all(informations)
    db.session.commit()

print("信息已添加")
# Out:
# 已删除 ../uploads 下的所有文件
# 共100张头像
# 已复制头像
# 共100个昵称
# 信息已添加

# %% [markdown]
# ## 生成景点

# %%
import random
from datetime import time
from app.models import Spot
from app.extensions import db
from app import app
from pathlib import Path
from shutil import copy
import os

titles = [
    "老虎石海上公园",
    "山海关古城",
    "新澳海底世界",
    "碧螺塔酒吧公园",
    "野生动物园",
    "南戴河国际娱乐中心",
    "秦皇求仙入海处",
    "联峰山公园",
    "燕塞湖",
    "角山长城",
    "鸽子窝公园",
    "怪楼奇园",
    "仙螺岛景区",
    "老龙头",
    "哒哒岛旅游度假区",
    "半岛公园",
    "黄金海岸",
    "碣石山风景区",
    "奥林匹克大道公园",
    "秦皇岛森林公园",
]

image_folder = "./spot-imgs"
all_images = [
    f for f in os.listdir(image_folder) if f.lower().endswith((".jpg", ".png", ".jpeg"))
]

spots = []

distinct_index = [0, 1, 2, 0, 2, 0, 2, 2, 2, 2, 0, 0, 0, 0, 0, 2, 3, 3, 0, 2]
coordinates = [
    "119.488542,39.813902",
    "119.760042,40.01084",
    "119.562879,39.906134",
    "119.535365,39.82047",
    "119.521386,39.870255",
    "119.354625,39.735548",
    "119.622324,39.913949",
    "119.458809,39.824137",
    "119.704406,40.043875",
    "119.738222,40.039337",
    "119.526688,39.836216",
    "119.498241,39.827084",
    "119.431375,39.793113",
    "119.797255,39.968241",
    "119.399937,39.786491",
    "119.515209,39.899569",
    "119.341343,39.701754",
    "119.145666,39.756307",
    "119.514722,39.827887",
    "119.538652,39.934709",
]

image_folder = "./images2"
image_url_prefix = "https://localhost:5000/download/"
content = """**{title}**位于{position}，是一个集自然景观与人文历史于一体的旅游景点。

## 主要特色

- 地处优越，风光旖旎，气候宜人
- 是观赏自然景观的绝佳地点
- 拥有丰富的生态资源
- 每年吸引大量游客，是休闲好去处

## 交通信息

> 地址：{position}知名景点附近
> 可乘坐多路公交车直达

---

欢迎前往**{title}**，感受自然与文化的魅力！
"""

areas = ["北戴河区", "山海关区", "海港区", "昌黎县"]

for index in range(len(titles)):
    title = titles[index]
    selected_images = random.sample(all_images, k=random.randint(4, 8))
    picture_urls = ",".join(image_url_prefix + img for img in selected_images)
    full_address = "河北省秦皇岛市" + title
    position = f"河北省秦皇岛市{areas[distinct_index[index]]}"

    spot = Spot(
        title=title,
        good=50 + index * 3,
        bad=5 + index % 4,
        start_time=time(8, 0),
        end_time=time(21, 0),
        position=position,
        coordinates=coordinates[index],
        content=content.format(title=title, position=position),
        pictures=picture_urls,
        province="河北省",
        city="秦皇岛市",
        place=areas[distinct_index[index]],
        views=100 + index * 10,
    )
    spots.append(spot)

with app.app_context():
    db.session.add_all(spots)
    db.session.commit()

print(f"已添加{len(spots)}个景点")

# 复制文件
folder = Path('./spot-imgs/')

imgs = [f for f in folder.iterdir() if f.is_file()]

print(f"共{len(imgs)}张照片")

for img in imgs:
    copy(img, f'../uploads/{img.name}')

print(f"已复制{len(imgs)}张照片")
# Out:
# 已添加20个景点
# 共14张照片
# 已复制14张照片

# %% [markdown]
# ## 新增帖子
#
# 这些信息都从csv文件中读取并生成。

# %%
import random
import time

import pandas as pd

from app.extensions import db
from app.models import Post, Comment, Category, Relationship

print("正在从 CSV 文件加载数据...")
categories_df = pd.read_csv("./post/categories.csv")
posts_df = pd.read_csv("./post/posts.csv")
comments_df = pd.read_csv("./post/comments.csv")
relationships_df = pd.read_csv("./post/relationships.csv")

print("正在调整帖子和评论中的 user_id，确保在 1 到 50 范围内...")
# 将 user_id 映射到 1 到 50 的范围：user_id = (user_id - 1) % 50 + 1
posts_df["user_id"] = posts_df["user_id"].apply(lambda x: (x - 1) % 50 + 1)
comments_df["user_id"] = comments_df["user_id"].apply(lambda x: (x - 1) % 50 + 1)

with app.app_context():
    print("正在将分类数据保存到数据库...")
    try:
        # 获取已存在的分类 ID
        existing_category_ids = set(category.id for category in Category.query.all())
        categories_to_insert = []

        for _, row in categories_df.iterrows():
            category_id = row["id"]
            if category_id in existing_category_ids:
                print(f"分类 ID {category_id} 已存在，跳过插入...")
                continue

            category = Category(
                id=category_id,
                name=row["name"],
                description=row["description"],
            )
            categories_to_insert.append(category)
            print(f"已准备分类 {category_id}：{row['name']}")

        if categories_to_insert:
            db.session.bulk_save_objects(categories_to_insert)
            db.session.commit()
            print(f"成功插入 {len(categories_to_insert)} 个新分类。")
        else:
            print("无需插入新分类，所有分类已存在。")
    except Exception as e:
        db.session.rollback()
        print(f"插入分类时出错：{e}")

    print("正在将帖子数据保存到数据库...")
    try:
        # 获取已存在的帖子 ID
        existing_post_ids = set(post.id for post in Post.query.all())
        posts_to_insert = []

        for _, row in posts_df.iterrows():
            post_id = row["id"]
            if post_id in existing_post_ids:
                print(f"帖子 ID {post_id} 已存在，跳过插入...")
                continue

            post = Post(
                id=post_id,
                user_id=row["user_id"],
                title=row["title"],
                content=row["content"],
                create_time=time.time() - random.randint(0, 24 * 60 * 60 * 30),
                update_time=time.time() - random.randint(0, 24 * 60 * 60 * 30),
                # comment_count=0,  # 初始为 0，后面更新
            )
            posts_to_insert.append(post)
            print(f"已准备帖子 {post_id}：{row['title']}")

        if posts_to_insert:
            db.session.bulk_save_objects(posts_to_insert)
            db.session.commit()
            print(f"成功插入 {len(posts_to_insert)} 个新帖子。")
        else:
            print("无需插入新帖子，所有帖子已存在。")
    except Exception as e:
        db.session.rollback()
        print(f"插入帖子时出错：{e}")

    print("正在将关系数据保存到数据库...")
    try:
        # 获取已存在的关系 ID
        existing_relationship_ids = set(
            relationship.id for relationship in Relationship.query.all()
        )
        relationships_to_insert = []

        for _, row in relationships_df.iterrows():
            relationship_id = row["id"]
            if relationship_id in existing_relationship_ids:
                print(f"关系 ID {relationship_id} 已存在，跳过插入...")
                continue

            relationship = Relationship(
                id=relationship_id,
                category_id=row["category_id"],
                post_id=row["post_id"],
            )
            relationships_to_insert.append(relationship)
            print(
                f"已准备关系 {relationship_id}：分类 {row['category_id']} - 帖子 {row['post_id']}"
            )

        if relationships_to_insert:
            db.session.bulk_save_objects(relationships_to_insert)
            db.session.commit()
            print(f"成功插入 {len(relationships_to_insert)} 个新关系。")
        else:
            print("无需插入新关系，所有关系已存在。")
    except Exception as e:
        db.session.rollback()
        print(f"插入关系时出错：{e}")

    try:
        # 获取已存在的评论 ID
        existing_comment_ids = set(comment.id for comment in Comment.query.all())
        comments_to_insert = []

        for _, row in comments_df.iterrows():
            comment_id = row["id"]
            if comment_id in existing_comment_ids:
                print(f"评论 ID {comment_id} 已存在，跳过插入...")
                continue

            comment = Comment(
                id=comment_id,
                user_id=row["user_id"],
                post_id=row["post_id"],
                parent_id=row["parent_id"] if pd.notna(row["parent_id"]) else None,
                content=row["content"],
                create_time=time.time() - random.randint(0, 24 * 60 * 60 * 30),
            )
            comments_to_insert.append(comment)
            print(f"已准备评论 {comment_id}：帖子 {row['post_id']}")

        if comments_to_insert:
            db.session.bulk_save_objects(comments_to_insert)
            db.session.commit()
            print(f"成功插入 {len(comments_to_insert)} 条新评论。")
        else:
            print("无需插入新评论，所有评论已存在。")
    except Exception as e:
        db.session.rollback()
        print(f"插入评论时出错：{e}")

    print("正在更新帖子的评论数量...")
    try:
        for post_id in posts_df["id"]:
            # 使用 db.session.get() 替代 Post.query.get()
            post = db.session.get(Post, post_id)
            if post:
                comment_count = Comment.query.filter_by(post_id=post_id).count()
                post.comment_count = comment_count
        db.session.commit()
        print("评论数量更新完成。")
    except Exception as e:
        db.session.rollback()
        print(f"更新评论数量时出错：{e}")
# Out:
# 正在从 CSV 文件加载数据...
# 正在调整帖子和评论中的 user_id，确保在 1 到 50 范围内...
# 正在将分类数据保存到数据库...
# 已准备分类 1：景点推荐
# 已准备分类 2：美食攻略
# 已准备分类 3：旅行日记
# 已准备分类 4：文化探索
# 已准备分类 5：海滨体验
# 已准备评论 498：帖子 60
# 已准备评论 499：帖子 116
# 已准备评论 500：帖子 172
# 成功插入 500 条新评论。
# 正在更新帖子的评论数量...
# 评论数量更新完成。

# %% [markdown]
# ## 插入图片

# %%
import random
import shutil
import string
from pathlib import Path

from flask import current_app

from app.config import backend_url
from app.extensions import db
from app.models import Post, Attachment

# 定义图片文件的常见扩展名及其对应的 MIME 类型
IMAGE_EXTENSIONS = {
    ".jpg": "image/jpeg",
    ".jpeg": "image/jpeg",
    ".png": "image/png",
    ".gif": "image/gif",
    ".bmp": "image/bmp",
    ".tiff": "image/tiff",
    ".webp": "image/webp",
}

def generate_random_string(length=8):
    """生成指定长度的随机字符串（字母和数字）"""
    characters = string.ascii_letters + string.digits
    return "".join(random.choice(characters) for _ in range(length))

def rename_and_collect_images():
    """遍历 images 文件夹，重命名图片，并返回图片信息"""
    current_dir = Path('.').parent
    images_dir = current_dir / "post-imgs"

    if not images_dir.exists() or not images_dir.is_dir():
        print("错误：images 文件夹不存在！")
        return []

    image_info_list = []
    used_names = set()

    for file_path in images_dir.iterdir():
        if not file_path.is_file():
            continue

        extension = file_path.suffix.lower()
        if extension not in IMAGE_EXTENSIONS:
            print(f"跳过非图片文件：{file_path.name}")
            continue

        while True:
            new_name = generate_random_string(8)
            if new_name not in used_names:
                used_names.add(new_name)
                break

        new_file_name = f"{new_name}{extension}"
        new_file_path = images_dir / new_file_name

        try:
            file_path.rename(new_file_path)
            print(f"已重命名：{file_path.name} -> {new_file_name}")
            image_info_list.append(
                {
                    "file_name": new_file_name,
                    "extension": extension,
                    "file_type": IMAGE_EXTENSIONS[extension],
                }
            )
        except Exception as e:
            print(f"重命名失败：{file_path.name} -> {new_file_name}，错误：{e}")

    return image_info_list

def clear_uploads_except_special():
    """清理 uploads 文件夹，保留以 avatar 和 wallpaper 开头的文件"""
    current_dir = Path('.').parent
    uploads_dir = current_dir / ".." / "uploads"

    # 如果 uploads 文件夹不存在，直接返回
    if not uploads_dir.exists() or not uploads_dir.is_dir():
        print("uploads 文件夹不存在，无需清理")
        return

    # 遍历 uploads 文件夹中的所有文件
    for file_path in uploads_dir.iterdir():
        if not file_path.is_file():
            continue

        file_name = file_path.name
        # 保留以 "avatar" 或 "wallpaper" 开头的文件
        if file_name.startswith("avatar") or file_name.startswith("wallpaper"):
            continue

        # 删除其他文件
        try:
            file_path.unlink()
            print(f"已删除：{file_name}")
        except Exception as e:
            print(f"删除失败：{file_name}，错误：{e}")

def copy_images_to_uploads():
    """将 images 文件夹中的图片复制到 ../uploads 文件夹"""
    current_dir = Path('.').parent
    images_dir = current_dir / "post-imgs"
    uploads_dir = current_dir / ".." / "uploads"

    # 确保 uploads 文件夹存在
    uploads_dir.mkdir(parents=True, exist_ok=True)

    # 遍历 images 文件夹中的所有文件
    for file_path in images_dir.iterdir():
        if not file_path.is_file():
            continue

        extension = file_path.suffix.lower()
        if extension not in IMAGE_EXTENSIONS:
            continue

        target_path = uploads_dir / file_path.name

        try:
            shutil.copy2(file_path, target_path)
            print(f"已复制：{file_path.name} -> {target_path}")
        except Exception as e:
            print(f"复制失败：{file_path.name} -> {target_path}，错误：{e}")

def add_attachments_to_posts():
    """为每个 Post 添加 3~7 个 Attachment"""
    image_info_list = rename_and_collect_images()
    if not image_info_list:
        print("没有可用的图片，无法添加 Attachment！")
        return

    copy_images_to_uploads()

    posts = Post.query.all()
    if not posts:
        print("没有找到任何 Post，无法添加 Attachment！")
        return

    for post in posts:
        num_attachments = random.randint(1, 6)
        selected_images = random.sample(
            image_info_list, k=min(num_attachments, len(image_info_list))
        )

        while len(selected_images) < num_attachments:
            selected_images.append(random.choice(image_info_list))

        for image_info in selected_images:
            file_name = image_info["file_name"]
            file_type = image_info["file_type"]
            file_path = f"{backend_url}/download/{file_name}"

            attachment = Attachment(
                post_id=post.id,
                file_name=file_name,
                file_path=file_path,
                file_type=file_type,
            )
            db.session.add(attachment)
            print(f"已为 Post {post.id} 添加 Attachment：{file_name}")

    try:
        db.session.commit()
        print("所有 Attachment 已成功添加到数据库！")
    except Exception as e:
        db.session.rollback()
        print(f"添加 Attachment 失败：{e}")

def main():
    print("开始为 Post 添加 Attachment...")
    with current_app.app_context():
        add_attachments_to_posts()
    print("操作完成！")

if __name__ == "__main__":
    from app import app
    with app.app_context():
        main()
# Out:
# 开始为 Post 添加 Attachment...
# 已重命名：hKkcKxrd.jpg -> ykYNGNpp.jpg
# 已重命名：RswNY1aa.jpg -> vhmG6kRZ.jpg
# 已重命名：xNaHJ0iz.jpg -> mtZbrpWZ.jpg
# 已重命名：FtDP6OMs.jpg -> m6fM7dLN.jpg
# 已重命名：zGV4Bi86.jpg -> ylHi7bPL.jpg
# 已重命名：IiTwP4La.jpg -> rboNTQX6.jpg
# 已重命名：Zy9dmllq.jpg -> eh0rcCYz.jpg
# 已重命名：gm3RvX3n.jpg -> S1Ihi6Vn.jpg
# 已重命名：m3zyuAM3.jpg -> dMA2ABx5.jpg
# 已重命名：Hz8NLune.jpg -> 0YF7AbHf.jpg
# 已重命名：kj60YwVh.jpg -> q11QX1SA.jpg
# 已重命名：zu4QSWIb.jpg -> 9rNMXiwO.jpg
# 已重命名：NtCW8Q5T.jpg -> zJ4y3GIn.jpg
# 已重命名：nHKju5Qd.jpg -> rVWM8Pxn.jpg
# 已重命名：g8Mxi3fj.jpg -> egdviLfx.jpg
# 已重命名：wEdk4izt.jpg -> 5AuwJ2jR.jpg
# 已重命名：Y7ALJprY.jpg -> WomyVwCk.jpg
# 已重命名：mGVaZx7S.jpg -> XiOiyDnJ.jpg
# 已重命名：BpGNVy6P.jpg -> M0OGXVDH.jpg
# 已重命名：Lw45e6cN.jpg -> Ejj6YvAc.jpg
# 已重命名：3WhhIzqz.jpg -> EdJ7hHEw.jpg
# 已重命名：yPRe6wob.jpg -> qWT8r7Ef.jpg
# 已重命名：vJL3XUP2.jpg -> PnmXjrwA.jpg
# 已重命名：EEE1YaSK.jpg -> MfIZfPyZ.jpg
# 已重命名：aQtv5GGk.jpg -> KDxaJaUF.jpg
# 已重命名：5FXfrB3t.jpg -> 5dE8s8GT.jpg
# 已重命名：P3ffSSP7.jpg -> r6uYdlNY.jpg
# 已重命名：ZaPEBGBk.jpg -> rjR59Olo.jpg
# 已重命名：LEl2oQWi.jpg -> 9CYMumNI.jpg
# 已复制：qWT8r7Ef.jpg -> ../uploads/qWT8r7Ef.jpg
# 已复制：m6fM7dLN.jpg -> ../uploads/m6fM7dLN.jpg
# 已复制：rjR59Olo.jpg -> ../uploads/rjR59Olo.jpg
# 已复制：q11QX1SA.jpg -> ../uploads/q11QX1SA.jpg
# 已复制：rboNTQX6.jpg -> ../uploads/rboNTQX6.jpg
# 已复制：rVWM8Pxn.jpg -> ../uploads/rVWM8Pxn.jpg
# 已复制：0YF7AbHf.jpg -> ../uploads/0YF7AbHf.jpg
# 已复制：zJ4y3GIn.jpg -> ../uploads/zJ4y3GIn.jpg
# 已复制：9CYMumNI.jpg -> ../uploads/9CYMumNI.jpg
# 已复制：EdJ7hHEw.jpg -> ../uploads/EdJ7hHEw.jpg
# 已复制：r6uYdlNY.jpg -> ../uploads/r6uYdlNY.jpg
# 已复制：5AuwJ2jR.jpg -> ../uploads/5AuwJ2jR.jpg
# 已复制：mtZbrpWZ.jpg -> ../uploads/mtZbrpWZ.jpg
# 已复制：egdviLfx.jpg -> ../uploads/egdviLfx.jpg
# 已复制：ylHi7bPL.jpg -> ../uploads/ylHi7bPL.jpg
# 已复制：KDxaJaUF.jpg -> ../uploads/KDxaJaUF.jpg
# 已复制：9rNMXiwO.jpg -> ../uploads/9rNMXiwO.jpg
# 已复制：ykYNGNpp.jpg -> ../uploads/ykYNGNpp.jpg
# 已复制：XiOiyDnJ.jpg -> ../uploads/XiOiyDnJ.jpg
# 已复制：M0OGXVDH.jpg -> ../uploads/M0OGXVDH.jpg
# 已复制：MfIZfPyZ.jpg -> ../uploads/MfIZfPyZ.jpg
# 已复制：S1Ihi6Vn.jpg -> ../uploads/S1Ihi6Vn.jpg
# 已复制：PnmXjrwA.jpg -> ../uploads/PnmXjrwA.jpg
# 已复制：eh0rcCYz.jpg -> ../uploads/eh0rcCYz.jpg
# 已复制：vhmG6kRZ.jpg -> ../uploads/vhmG6kRZ.jpg
# 已复制：5dE8s8GT.jpg -> ../uploads/5dE8s8GT.jpg
# 已复制：Ejj6YvAc.jpg -> ../uploads/Ejj6YvAc.jpg
# 已复制：WomyVwCk.jpg -> ../uploads/WomyVwCk.jpg
# 已复制：dMA2ABx5.jpg -> ../uploads/dMA2ABx5.jpg
# 已为 Post 1 添加 Attachment：9CYMumNI.jpg
# 已为 Post 1 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 2 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 3 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 3 添加 Attachment：WomyVwCk.jpg
# 已为 Post 3 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 3 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 4 添加 Attachment：egdviLfx.jpg
# 已为 Post 5 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 5 添加 Attachment：rjR59Olo.jpg
# 已为 Post 5 添加 Attachment：egdviLfx.jpg
# 已为 Post 5 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 5 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 6 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 6 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 6 添加 Attachment：9CYMumNI.jpg
# 已为 Post 6 添加 Attachment：q11QX1SA.jpg
# 已为 Post 7 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 7 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 7 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 8 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 8 添加 Attachment：rboNTQX6.jpg
# 已为 Post 8 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 9 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 9 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 9 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 10 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 10 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 10 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 11 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 11 添加 Attachment：rjR59Olo.jpg
# 已为 Post 12 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 12 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 12 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 12 添加 Attachment：egdviLfx.jpg
# 已为 Post 12 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 12 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 13 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 13 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 13 添加 Attachment：WomyVwCk.jpg
# 已为 Post 13 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 13 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 14 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 15 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 15 添加 Attachment：rjR59Olo.jpg
# 已为 Post 15 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 15 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 16 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 16 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 17 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 18 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 19 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 19 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 20 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 21 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 21 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 21 添加 Attachment：egdviLfx.jpg
# 已为 Post 22 添加 Attachment：rjR59Olo.jpg
# 已为 Post 22 添加 Attachment：q11QX1SA.jpg
# 已为 Post 22 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 22 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 23 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 23 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 23 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 23 添加 Attachment：egdviLfx.jpg
# 已为 Post 23 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 23 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 24 添加 Attachment：egdviLfx.jpg
# 已为 Post 24 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 24 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 24 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 24 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 25 添加 Attachment：9CYMumNI.jpg
# 已为 Post 25 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 25 添加 Attachment：WomyVwCk.jpg
# 已为 Post 25 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 25 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 25 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 26 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 26 添加 Attachment：WomyVwCk.jpg
# 已为 Post 26 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 26 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 26 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 26 添加 Attachment：9CYMumNI.jpg
# 已为 Post 27 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 28 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 28 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 28 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 28 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 28 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 28 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 29 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 30 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 30 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 30 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 30 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 30 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 30 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 31 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 31 添加 Attachment：9CYMumNI.jpg
# 已为 Post 31 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 32 添加 Attachment：q11QX1SA.jpg
# 已为 Post 33 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 33 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 33 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 33 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 34 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 34 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 34 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 34 添加 Attachment：rjR59Olo.jpg
# 已为 Post 35 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 35 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 35 添加 Attachment：rboNTQX6.jpg
# 已为 Post 36 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 36 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 36 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 37 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 37 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 37 添加 Attachment：rjR59Olo.jpg
# 已为 Post 37 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 38 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 38 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 39 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 39 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 40 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 40 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 40 添加 Attachment：q11QX1SA.jpg
# 已为 Post 40 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 41 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 41 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 41 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 42 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 42 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 42 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 43 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 44 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 45 添加 Attachment：rjR59Olo.jpg
# 已为 Post 45 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 45 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 45 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 45 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 46 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 47 添加 Attachment：WomyVwCk.jpg
# 已为 Post 48 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 48 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 48 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 49 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 49 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 49 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 49 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 49 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 49 添加 Attachment：rjR59Olo.jpg
# 已为 Post 50 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 50 添加 Attachment：9CYMumNI.jpg
# 已为 Post 50 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 50 添加 Attachment：rboNTQX6.jpg
# 已为 Post 50 添加 Attachment：q11QX1SA.jpg
# 已为 Post 50 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 51 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 51 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 51 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 52 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 53 添加 Attachment：rboNTQX6.jpg
# 已为 Post 53 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 54 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 54 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 55 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 55 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 55 添加 Attachment：WomyVwCk.jpg
# 已为 Post 55 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 55 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 55 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 56 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 56 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 57 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 57 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 57 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 57 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 57 添加 Attachment：9CYMumNI.jpg
# 已为 Post 58 添加 Attachment：rboNTQX6.jpg
# 已为 Post 58 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 59 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 59 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 60 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 60 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 60 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 60 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 61 添加 Attachment：rjR59Olo.jpg
# 已为 Post 61 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 61 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 62 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 62 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 62 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 62 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 62 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 62 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 63 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 64 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 65 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 65 添加 Attachment：rjR59Olo.jpg
# 已为 Post 65 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 65 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 65 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 65 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 66 添加 Attachment：egdviLfx.jpg
# 已为 Post 66 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 66 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 66 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 67 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 67 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 67 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 67 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 68 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 68 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 68 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 68 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 68 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 68 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 69 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 70 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 70 添加 Attachment：q11QX1SA.jpg
# 已为 Post 71 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 71 添加 Attachment：q11QX1SA.jpg
# 已为 Post 71 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 71 添加 Attachment：egdviLfx.jpg
# 已为 Post 72 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 72 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 73 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 73 添加 Attachment：rjR59Olo.jpg
# 已为 Post 74 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 75 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 76 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 76 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 76 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 76 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 76 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 77 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 77 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 77 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 77 添加 Attachment：q11QX1SA.jpg
# 已为 Post 78 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 78 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 78 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 78 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 78 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 78 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 79 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 79 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 79 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 79 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 80 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 80 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 80 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 80 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 80 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 81 添加 Attachment：WomyVwCk.jpg
# 已为 Post 81 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 81 添加 Attachment：9CYMumNI.jpg
# 已为 Post 81 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 81 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 81 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 82 添加 Attachment：9CYMumNI.jpg
# 已为 Post 82 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 82 添加 Attachment：rboNTQX6.jpg
# 已为 Post 82 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 82 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 83 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 83 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 83 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 83 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 84 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 84 添加 Attachment：9CYMumNI.jpg
# 已为 Post 85 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 86 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 86 添加 Attachment：WomyVwCk.jpg
# 已为 Post 86 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 86 添加 Attachment：rboNTQX6.jpg
# 已为 Post 86 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 86 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 87 添加 Attachment：9CYMumNI.jpg
# 已为 Post 88 添加 Attachment：WomyVwCk.jpg
# 已为 Post 88 添加 Attachment：egdviLfx.jpg
# 已为 Post 88 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 88 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 88 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 89 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 89 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 89 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 89 添加 Attachment：rboNTQX6.jpg
# 已为 Post 90 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 90 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 90 添加 Attachment：q11QX1SA.jpg
# 已为 Post 90 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 90 添加 Attachment：WomyVwCk.jpg
# 已为 Post 90 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 91 添加 Attachment：q11QX1SA.jpg
# 已为 Post 92 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 92 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 92 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 92 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 93 添加 Attachment：rboNTQX6.jpg
# 已为 Post 93 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 93 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 93 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 94 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 94 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 94 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 94 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 94 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 95 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 96 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 96 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 96 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 96 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 96 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 96 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 97 添加 Attachment：9CYMumNI.jpg
# 已为 Post 98 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 99 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 99 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 99 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 100 添加 Attachment：WomyVwCk.jpg
# 已为 Post 100 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 100 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 100 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 100 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 100 添加 Attachment：egdviLfx.jpg
# 已为 Post 101 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 101 添加 Attachment：9CYMumNI.jpg
# 已为 Post 101 添加 Attachment：egdviLfx.jpg
# 已为 Post 101 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 101 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 102 添加 Attachment：q11QX1SA.jpg
# 已为 Post 102 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 102 添加 Attachment：rboNTQX6.jpg
# 已为 Post 102 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 102 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 102 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 103 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 103 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 103 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 103 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 103 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 104 添加 Attachment：q11QX1SA.jpg
# 已为 Post 104 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 104 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 105 添加 Attachment：rboNTQX6.jpg
# 已为 Post 105 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 105 添加 Attachment：WomyVwCk.jpg
# 已为 Post 106 添加 Attachment：9CYMumNI.jpg
# 已为 Post 106 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 106 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 106 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 106 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 106 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 107 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 107 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 107 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 107 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 107 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 108 添加 Attachment：WomyVwCk.jpg
# 已为 Post 108 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 109 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 109 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 109 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 109 添加 Attachment：q11QX1SA.jpg
# 已为 Post 109 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 110 添加 Attachment：9CYMumNI.jpg
# 已为 Post 110 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 111 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 111 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 112 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 112 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 112 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 113 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 113 添加 Attachment：rboNTQX6.jpg
# 已为 Post 113 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 113 添加 Attachment：WomyVwCk.jpg
# 已为 Post 113 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 114 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 114 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 114 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 114 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 114 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 115 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 115 添加 Attachment：9CYMumNI.jpg
# 已为 Post 115 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 116 添加 Attachment：rjR59Olo.jpg
# 已为 Post 117 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 117 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 117 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 117 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 117 添加 Attachment：WomyVwCk.jpg
# 已为 Post 118 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 119 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 119 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 119 添加 Attachment：q11QX1SA.jpg
# 已为 Post 119 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 120 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 120 添加 Attachment：q11QX1SA.jpg
# 已为 Post 120 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 121 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 121 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 122 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 122 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 123 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 123 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 124 添加 Attachment：9CYMumNI.jpg
# 已为 Post 124 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 124 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 125 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 125 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 125 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 125 添加 Attachment：rjR59Olo.jpg
# 已为 Post 126 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 126 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 126 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 126 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 126 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 126 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 127 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 127 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 127 添加 Attachment：q11QX1SA.jpg
# 已为 Post 127 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 127 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 128 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 128 添加 Attachment：rboNTQX6.jpg
# 已为 Post 129 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 130 添加 Attachment：q11QX1SA.jpg
# 已为 Post 130 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 130 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 130 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 131 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 131 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 131 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 131 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 131 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 131 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 132 添加 Attachment：WomyVwCk.jpg
# 已为 Post 132 添加 Attachment：9CYMumNI.jpg
# 已为 Post 133 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 134 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 134 添加 Attachment：egdviLfx.jpg
# 已为 Post 134 添加 Attachment：rjR59Olo.jpg
# 已为 Post 134 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 135 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 135 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 135 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 136 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 136 添加 Attachment：9CYMumNI.jpg
# 已为 Post 136 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 137 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 137 添加 Attachment：rboNTQX6.jpg
# 已为 Post 137 添加 Attachment：9CYMumNI.jpg
# 已为 Post 137 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 137 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 138 添加 Attachment：q11QX1SA.jpg
# 已为 Post 138 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 139 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 139 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 140 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 140 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 140 添加 Attachment：WomyVwCk.jpg
# 已为 Post 140 添加 Attachment：egdviLfx.jpg
# 已为 Post 140 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 141 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 142 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 142 添加 Attachment：WomyVwCk.jpg
# 已为 Post 142 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 142 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 142 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 142 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 143 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 143 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 144 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 144 添加 Attachment：WomyVwCk.jpg
# 已为 Post 145 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 146 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 146 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 147 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 147 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 147 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 147 添加 Attachment：rboNTQX6.jpg
# 已为 Post 147 添加 Attachment：q11QX1SA.jpg
# 已为 Post 148 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 148 添加 Attachment：WomyVwCk.jpg
# 已为 Post 148 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 149 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 149 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 150 添加 Attachment：9CYMumNI.jpg
# 已为 Post 150 添加 Attachment：q11QX1SA.jpg
# 已为 Post 150 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 150 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 151 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 152 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 152 添加 Attachment：9CYMumNI.jpg
# 已为 Post 152 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 152 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 152 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 152 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 153 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 153 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 153 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 153 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 154 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 154 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 154 添加 Attachment：rjR59Olo.jpg
# 已为 Post 154 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 154 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 154 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 155 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 155 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 155 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 155 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 156 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 156 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 156 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 156 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 156 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 157 添加 Attachment：egdviLfx.jpg
# 已为 Post 157 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 158 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 158 添加 Attachment：egdviLfx.jpg
# 已为 Post 159 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 159 添加 Attachment：egdviLfx.jpg
# 已为 Post 159 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 159 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 160 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 160 添加 Attachment：9CYMumNI.jpg
# 已为 Post 161 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 162 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 162 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 162 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 162 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 162 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 163 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 163 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 163 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 163 添加 Attachment：rboNTQX6.jpg
# 已为 Post 164 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 164 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 164 添加 Attachment：q11QX1SA.jpg
# 已为 Post 164 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 164 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 165 添加 Attachment：rjR59Olo.jpg
# 已为 Post 165 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 165 添加 Attachment：egdviLfx.jpg
# 已为 Post 166 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 166 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 167 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 167 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 167 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 167 添加 Attachment：rjR59Olo.jpg
# 已为 Post 167 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 168 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 168 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 168 添加 Attachment：egdviLfx.jpg
# 已为 Post 169 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 169 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 169 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 169 添加 Attachment：q11QX1SA.jpg
# 已为 Post 170 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 170 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 171 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 171 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 171 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 172 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 172 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 172 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 172 添加 Attachment：9rNMXiwO.jpg
# 已为 Post 172 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 173 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 174 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 174 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 174 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 174 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 175 添加 Attachment：rboNTQX6.jpg
# 已为 Post 176 添加 Attachment：egdviLfx.jpg
# 已为 Post 176 添加 Attachment：rboNTQX6.jpg
# 已为 Post 176 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 176 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 177 添加 Attachment：9CYMumNI.jpg
# 已为 Post 177 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 178 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 179 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 179 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 180 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 180 添加 Attachment：egdviLfx.jpg
# 已为 Post 180 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 180 添加 Attachment：WomyVwCk.jpg
# 已为 Post 180 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 181 添加 Attachment：q11QX1SA.jpg
# 已为 Post 182 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 182 添加 Attachment：9CYMumNI.jpg
# 已为 Post 182 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 182 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 182 添加 Attachment：egdviLfx.jpg
# 已为 Post 183 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 183 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 183 添加 Attachment：S1Ihi6Vn.jpg
# 已为 Post 183 添加 Attachment：rboNTQX6.jpg
# 已为 Post 183 添加 Attachment：egdviLfx.jpg
# 已为 Post 183 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 184 添加 Attachment：qWT8r7Ef.jpg
# 已为 Post 185 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 186 添加 Attachment：vhmG6kRZ.jpg
# 已为 Post 186 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 186 添加 Attachment：PnmXjrwA.jpg
# 已为 Post 186 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 187 添加 Attachment：rboNTQX6.jpg
# 已为 Post 187 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 187 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 187 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 187 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 187 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 188 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 188 添加 Attachment：rjR59Olo.jpg
# 已为 Post 188 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 189 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 189 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 190 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 190 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 191 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 191 添加 Attachment：q11QX1SA.jpg
# 已为 Post 191 添加 Attachment：rboNTQX6.jpg
# 已为 Post 191 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 192 添加 Attachment：M0OGXVDH.jpg
# 已为 Post 192 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 192 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 192 添加 Attachment：zJ4y3GIn.jpg
# 已为 Post 192 添加 Attachment：rboNTQX6.jpg
# 已为 Post 192 添加 Attachment：9CYMumNI.jpg
# 已为 Post 193 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 193 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 193 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 193 添加 Attachment：5dE8s8GT.jpg
# 已为 Post 193 添加 Attachment：Ejj6YvAc.jpg
# 已为 Post 194 添加 Attachment：eh0rcCYz.jpg
# 已为 Post 194 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 194 添加 Attachment：rjR59Olo.jpg
# 已为 Post 194 添加 Attachment：mtZbrpWZ.jpg
# 已为 Post 194 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 194 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 195 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 195 添加 Attachment：0YF7AbHf.jpg
# 已为 Post 195 添加 Attachment：m6fM7dLN.jpg
# 已为 Post 195 添加 Attachment：q11QX1SA.jpg
# 已为 Post 195 添加 Attachment：WomyVwCk.jpg
# 已为 Post 196 添加 Attachment：rVWM8Pxn.jpg
# 已为 Post 197 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 197 添加 Attachment：XiOiyDnJ.jpg
# 已为 Post 197 添加 Attachment：KDxaJaUF.jpg
# 已为 Post 197 添加 Attachment：ylHi7bPL.jpg
# 已为 Post 198 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 198 添加 Attachment：EdJ7hHEw.jpg
# 已为 Post 198 添加 Attachment：MfIZfPyZ.jpg
# 已为 Post 199 添加 Attachment：9CYMumNI.jpg
# 已为 Post 199 添加 Attachment：q11QX1SA.jpg
# 已为 Post 199 添加 Attachment：r6uYdlNY.jpg
# 已为 Post 199 添加 Attachment：dMA2ABx5.jpg
# 已为 Post 199 添加 Attachment：5AuwJ2jR.jpg
# 已为 Post 199 添加 Attachment：ykYNGNpp.jpg
# 已为 Post 200 添加 Attachment：egdviLfx.jpg
# 已为 Post 200 添加 Attachment：XiOiyDnJ.jpg
# 所有 Attachment 已成功添加到数据库！
# 操作完成！

# %% [markdown]
# ## 生成关注和订阅

# %%
import random

from app.extensions import db
from app.models import User, Subscribe

def insert_random_subscriptions():
    print("正在插入随机订阅数据（两两组合，0.05 概率）...")
    try:
        # 获取所有用户
        existing_users = User.query.all()
        user_count = len(existing_users)
        print(f"当前用户总数: {user_count}")

        if user_count < 50:
            print(f"错误：用户数 {user_count} 小于 50，无法生成完整订阅数据")
            return
        elif user_count > 50:
            print(f"警告：用户数 {user_count} 多于 50，将使用所有用户生成订阅数据")

        # 清空现有的 Subscribe 表（可选）
        db.session.query(Subscribe).delete()
        db.session.commit()
        print("已清空 Subscribe 表")

        # 生成订阅关系
        subscriptions_to_insert = []
        for i in range(user_count):
            for j in range(user_count):
                if i != j:  # 避免自己关注自己
                    user1 = existing_users[i]
                    user2 = existing_users[j]
                    # 以 0.05 概率生成订阅关系
                    if random.random() < 0.05:
                        subscription = Subscribe(
                            user_id=user1.id,
                            subscribed_user_id=user2.id
                        )
                        subscriptions_to_insert.append(subscription)
                        print(f"已准备订阅关系: 用户 {user1.id} -> 用户 {user2.id}")

        # 插入订阅数据
        if subscriptions_to_insert:
            db.session.bulk_save_objects(subscriptions_to_insert)
            db.session.commit()
            print(f"成功插入 {len(subscriptions_to_insert)} 条订阅记录")
        else:
            print("未生成任何订阅关系（可能是概率太低或用户数不足）")

        # 验证插入结果
        sample_subscriptions = db.session.query(Subscribe).limit(5).all()
        print(f"Subscribe 表示例数据: {[s.json for s in sample_subscriptions]}")

    except Exception as e:
        db.session.rollback()
        print(f"插入订阅数据时出错：{type(e).__name__} - {str(e)}")
        return False

    return True

# 主函数
def main():
    # 确保表结构已创建
    try:
        db.create_all()
    except Exception as e:
        print(f"创建表结构时出错：{e}")
        return

    # 执行插入订阅数据
    if not insert_random_subscriptions():
        print("订阅数据插入失败")
        return

    print("订阅数据插入完成！")

from app import app

with app.app_context():
    main()
# Out:
# 正在插入随机订阅数据（两两组合，0.05 概率）...
# 当前用户总数: 50
# 已清空 Subscribe 表
# 已准备订阅关系: 用户 1 -> 用户 27
# 已准备订阅关系: 用户 1 -> 用户 34
# 已准备订阅关系: 用户 2 -> 用户 13
# 已准备订阅关系: 用户 2 -> 用户 19
# 已准备订阅关系: 用户 2 -> 用户 38
# 已准备订阅关系: 用户 3 -> 用户 31
# 已准备订阅关系: 用户 3 -> 用户 47
# 已准备订阅关系: 用户 4 -> 用户 21
# 已准备订阅关系: 用户 4 -> 用户 38
# 已准备订阅关系: 用户 5 -> 用户 35
# 已准备订阅关系: 用户 5 -> 用户 42
# 已准备订阅关系: 用户 5 -> 用户 43
# 已准备订阅关系: 用户 6 -> 用户 5
# 已准备订阅关系: 用户 6 -> 用户 9
# 已准备订阅关系: 用户 6 -> 用户 11
# 已准备订阅关系: 用户 6 -> 用户 20
# 已准备订阅关系: 用户 8 -> 用户 40
# 已准备订阅关系: 用户 9 -> 用户 8
# 已准备订阅关系: 用户 10 -> 用户 11
# 已准备订阅关系: 用户 10 -> 用户 12
# 已准备订阅关系: 用户 10 -> 用户 17
# 已准备订阅关系: 用户 10 -> 用户 20
# 已准备订阅关系: 用户 10 -> 用户 37
# 已准备订阅关系: 用户 10 -> 用户 48
# 已准备订阅关系: 用户 11 -> 用户 15
# 已准备订阅关系: 用户 11 -> 用户 35
# 已准备订阅关系: 用户 12 -> 用户 2
# 已准备订阅关系: 用户 12 -> 用户 8
# 已准备订阅关系: 用户 12 -> 用户 13
# 已准备订阅关系: 用户 12 -> 用户 21
# 已准备订阅关系: 用户 13 -> 用户 10
# 已准备订阅关系: 用户 13 -> 用户 36
# 已准备订阅关系: 用户 13 -> 用户 49
# 已准备订阅关系: 用户 14 -> 用户 8
# 已准备订阅关系: 用户 14 -> 用户 32
# 已准备订阅关系: 用户 14 -> 用户 36
# 已准备订阅关系: 用户 15 -> 用户 19
# 已准备订阅关系: 用户 15 -> 用户 32
# 已准备订阅关系: 用户 15 -> 用户 35
# 已准备订阅关系: 用户 15 -> 用户 45
# 已准备订阅关系: 用户 16 -> 用户 1
# 已准备订阅关系: 用户 16 -> 用户 13
# 已准备订阅关系: 用户 17 -> 用户 30
# 已准备订阅关系: 用户 18 -> 用户 13
# 已准备订阅关系: 用户 18 -> 用户 21
# 已准备订阅关系: 用户 18 -> 用户 28
# 已准备订阅关系: 用户 19 -> 用户 6
# 已准备订阅关系: 用户 19 -> 用户 12
# 已准备订阅关系: 用户 19 -> 用户 20
# 已准备订阅关系: 用户 19 -> 用户 27
# 已准备订阅关系: 用户 19 -> 用户 35
# 已准备订阅关系: 用户 20 -> 用户 6
# 已准备订阅关系: 用户 20 -> 用户 16
# 已准备订阅关系: 用户 20 -> 用户 30
# 已准备订阅关系: 用户 20 -> 用户 35
# 已准备订阅关系: 用户 21 -> 用户 2
# 已准备订阅关系: 用户 21 -> 用户 5
# 已准备订阅关系: 用户 21 -> 用户 30
# 已准备订阅关系: 用户 22 -> 用户 1
# 已准备订阅关系: 用户 22 -> 用户 30
# 已准备订阅关系: 用户 22 -> 用户 35
# 已准备订阅关系: 用户 23 -> 用户 12
# 已准备订阅关系: 用户 23 -> 用户 39
# 已准备订阅关系: 用户 24 -> 用户 33
# 已准备订阅关系: 用户 24 -> 用户 39
# 已准备订阅关系: 用户 25 -> 用户 10
# 已准备订阅关系: 用户 25 -> 用户 14
# 已准备订阅关系: 用户 25 -> 用户 29
# 已准备订阅关系: 用户 25 -> 用户 36
# 已准备订阅关系: 用户 28 -> 用户 9
# 已准备订阅关系: 用户 28 -> 用户 23
# 已准备订阅关系: 用户 28 -> 用户 33
# 已准备订阅关系: 用户 28 -> 用户 35
# 已准备订阅关系: 用户 29 -> 用户 2
# 已准备订阅关系: 用户 29 -> 用户 6
# 已准备订阅关系: 用户 29 -> 用户 32
# 已准备订阅关系: 用户 30 -> 用户 12
# 已准备订阅关系: 用户 30 -> 用户 16
# 已准备订阅关系: 用户 31 -> 用户 34
# 已准备订阅关系: 用户 31 -> 用户 37
# 已准备订阅关系: 用户 31 -> 用户 47
# 已准备订阅关系: 用户 32 -> 用户 30
# 已准备订阅关系: 用户 33 -> 用户 8
# 已准备订阅关系: 用户 33 -> 用户 10
# 已准备订阅关系: 用户 33 -> 用户 14
# 已准备订阅关系: 用户 35 -> 用户 3
# 已准备订阅关系: 用户 35 -> 用户 39
# 已准备订阅关系: 用户 36 -> 用户 10
# 已准备订阅关系: 用户 36 -> 用户 20
# 已准备订阅关系: 用户 36 -> 用户 26
# 已准备订阅关系: 用户 36 -> 用户 37
# 已准备订阅关系: 用户 36 -> 用户 48
# 已准备订阅关系: 用户 37 -> 用户 22
# 已准备订阅关系: 用户 37 -> 用户 30
# 已准备订阅关系: 用户 37 -> 用户 42
# 已准备订阅关系: 用户 38 -> 用户 1
# 已准备订阅关系: 用户 38 -> 用户 36
# 已准备订阅关系: 用户 39 -> 用户 41
# 已准备订阅关系: 用户 40 -> 用户 1
# 已准备订阅关系: 用户 40 -> 用户 29
# 已准备订阅关系: 用户 41 -> 用户 8
# 已准备订阅关系: 用户 41 -> 用户 18
# 已准备订阅关系: 用户 41 -> 用户 39
# 已准备订阅关系: 用户 42 -> 用户 18
# 已准备订阅关系: 用户 42 -> 用户 29
# 已准备订阅关系: 用户 42 -> 用户 39
# 已准备订阅关系: 用户 43 -> 用户 18
# 已准备订阅关系: 用户 43 -> 用户 25
# 已准备订阅关系: 用户 44 -> 用户 24
# 已准备订阅关系: 用户 44 -> 用户 26
# 已准备订阅关系: 用户 46 -> 用户 44
# 已准备订阅关系: 用户 47 -> 用户 11
# 已准备订阅关系: 用户 47 -> 用户 14
# 已准备订阅关系: 用户 48 -> 用户 8
# 已准备订阅关系: 用户 48 -> 用户 26
# 已准备订阅关系: 用户 49 -> 用户 8
# 已准备订阅关系: 用户 49 -> 用户 31
# 已准备订阅关系: 用户 49 -> 用户 41
# 已准备订阅关系: 用户 50 -> 用户 5
# 已准备订阅关系: 用户 50 -> 用户 41
# 成功插入 120 条订阅记录
# Subscribe 表示例数据: [{'id': 1, 'user_id': 1, 'subscribed_user_id': 27}, {'id': 2, 'user_id': 1, 'subscribed_user_id': 34}, {'id': 3, 'user_id': 2, 'subscribed_user_id': 13}, {'id': 4, 'user_id': 2, 'subscribed_user_id': 19}, {'id': 5, 'user_id': 2, 'subscribed_user_id': 38}]
# 订阅数据插入完成！
